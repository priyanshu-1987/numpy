# %%
import numpy as np

# %%
mat1=np.array([[1,2],[3,4]])
mat2=np.array([[5,6],[7,8]])

# %%
mat1
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
mat2
# Out:
# array([[5, 6],
#        [7, 8]])

# %%
#Wrong multipication of matrix
mat1*mat2
# Out:
# array([[ 5, 12],
#        [21, 32]])

# %%
#Right multiplication of matrix
mat1 @ mat2
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
#we can also use for multiplication of matrix
np.dot(mat1,mat2)
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
#for Transpose of matrix
mat1.T
# Out:
# array([[1, 3],
#        [2, 4]])
