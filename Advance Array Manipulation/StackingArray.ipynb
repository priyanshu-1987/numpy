# %%
import numpy as np

# %%
A=np.array([1,2,3,4])
B=np.array([5,6,7,8])

# %%
#Stacking Array-->use vector not matrix
vertical=np.vstack((A,B))
horizontal=np.hstack((A,B))

# %%
vertical
# Out:
# array([[1, 2, 3, 4],
#        [5, 6, 7, 8]])

# %%
horizontal
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %%
np.column_stack((A,B))
# Out:
# array([[1, 5],
#        [2, 6],
#        [3, 7],
#        [4, 8]])
